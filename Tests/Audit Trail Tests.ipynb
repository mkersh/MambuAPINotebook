# %% [markdown]
# ## Mambu Audit Trail API - Tests

# %%
# %run ../API.py
# %run ../ENV.py
from IPython.core.display import HTML
setENV(ENV)

# %%
HEADERS = {'apikey': '{{mnenv_apikey}}'}
PARAMS = {'size': "10"}
r = GET('{{envMN}}/v1/events', headers=HEADERS, params=PARAMS, headerparts=APIKEYS)
PRINT(r)
# Out:
# API status: 200
# JSON Response:
# {
#     "events": [
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:14.790Z",
#             "request_method": "POST",
#             "request_payload": "{\"dataFetchingInfo\":{\"sortedColumn\":\"SENT_DATE\",\"sortingOrder\":\"DESCENDING\",\"dataPagination\":{\"offset\":0,\"numObjectToRetrieve\":25,\"includeTotalCount\":false,\"retrieveAllItems\":false}},\"dataItemsInfo\":{\"columns\":[\"TYPE\",\"SENT_DATE\",\"SENT_BY\",\"STATE\",\"DESTINATION\",\"MESSAGE\"],\"dataItemType\":\"NOTIFICATION_MESSAGE\",\"includeTotals\":false,\"countTotalNumItems\":true,\"generateDataItems\":true,\"asyncCountTotalNumItems\":true,\"countTimeoutEnabled\":false},\"dataViewType\":\"CLIENT_NOTIFICATION_MESSAGES\"}",
#             "request_uri": "/desktop/dispatch/GetDataItems",
#             "resource": "client",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.communications=.startindex=1.pagesize=25",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:14.518Z",
#             "request_method": "POST",
#             "request_payload": "{\"customFieldKeys\":[\"8a1948887117cd8601711aff6c0500d0\"]}",
#             "request_uri": "/desktop/dispatch/GetCustomFieldDependencyInfo",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:14.400Z",
#             "request_method": "POST",
#             "request_payload": "{\"types\":[\"LOAN_ACCOUNT_INFO\",\"TRANSACTION_CHANNEL_INFO\"],\"loadCustomFieldSelection\":false,\"loadCustomFieldLinks\":false,\"entityLinkedKey\":\"8a1948887117cd8601711aff6bff00c8\"}",
#             "request_uri": "/desktop/dispatch/GetCustomFieldSets",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:14.166Z",
#             "request_method": "POST",
#             "request_payload": "{\"entityKey\":\"8a19261d71ea2b3a0171ef25bb2e15f8\",\"dataFields\":[\"ACCOUNT_ID\",\"BRANCH_NAME\",\"ACCOUNT_STATE\",\"ACCOUNT_SUB_STATE\",\"ORIGINAL_ACCOUNT_NAME\",\"ORIGINAL_ACCOUNT_ID\",\"RESCHEDULED_ACCOUNT_NAME\",\"REFINANCED_ACCOUNT_NAME\",\"RESCHEDULED_ACCOUNT_ID\",\"REFINANCED_ACCOUNT_ID\",\"APPROVAL_DATE\",\"PRODUCT_NAME\",\"PRODUCT_REPAYMENT_SCHEDULE_METHOD\",\"LOAN_AMOUNT\",\"AVAILABLE_AMOUNT\",\"PERIODIC_PAYMENT\",\"DISBURSED_TRANCHES_AMOUNT\",\"INTEREST_RATE\",\"INTEREST_RATE_DASH\",\"INTEREST_CHARGE_FREQUENCY\",\"INTEREST_CALCULATION_METHOD\",\"INTEREST_TYPE\",\"INTEREST_APPLICATION_METHOD\",\"PAYMENT_METHOD\",\"REPAYMENT_SCHEDULE_METHOD\",\"REPAYMENT_PERIOD_UNIT\",\"REPAYMENT_PERIOD_COUNT\",\"NUM_INSTALLMENTS\",\"PRINCIPAL_REPAYMENT_INTERVAL\",\"PRINCIPAL_BALANCE\",\"CAPITALIZED_INTEREST\",\"INTEREST_BALANCE\",\"INTEREST_ACCRUED\",\"INTEREST_FROM_ARREARS_BALANCE\",\"INTEREST_FROM_ARREARS_ACCRUED\",\"INTEREST_FROM_ARREARS_DUE\",\"INTEREST_FROM_ARREARS_PAID\",\"PENALTY_ACCRUED\",\"PENALTY_CALCULATION_METHOD\",\"PENALTY_RATE\",\"ARREARS_TOLERANCE_PERIOD\",\"MONTHLY_ARREARS_TOLERANCE_DAY\",\"ARREARS_TOLERANCE_AMOUNT\",\"FEES_BALANCE\",\"HOLD_BALANCE\",\"PENALTY_BALANCE\",\"TOTAL_BALANCE\",\"PRINCIPAL_DUE\",\"INTEREST_DUE\",\"FEES_DUE\",\"PENALTY_DUE\",\"TOTAL_DUE\",\"PRINCIPAL_PAID\",\"INTEREST_PAID\",\"INTEREST_PREPAID\",\"FEES_PAID\",\"PENALTY_PAID\",\"TOTAL_PAID\",\"NOTES\",\"LAST_SET_TO_ARREARS_DATE\",\"DAYS_IN_ARREARS\",\"DAYS_LATE\",\"SCHEDULE_DUE_DATES_METHOD\",\"GRACE_PERIOD_COUNT\",\"GRACE_PERIOD_TYPE\",\"TAX_RATE\",\"INTEREST_SPREAD\",\"HYBRID_LOAN_NAME\",\"LAST_LOCKED_DATE\",\"FIRST_REPAYMENT_DATE\",\"PREPAYMENTS_RECALCULATION\",\"PRINCIPAL_PAID_INSTALLMENT_STATUS\",\"LATE_PAYMENT_RECALCULATION_METHOD\",\"APPLY_INTEREST_ON_PREPAYMENT_METHOD\",\"PREPAYMENT_ACCEPTANCE\",\"FUTURE_PAYMENTS_ACCEPTANCE\",\"ACCRUE_LATE_INTEREST\",\"WITHDRAWAL_REDRAW_LIMITATION\",\"REDRAW_BALANCE\",\"EXPECTED_PRINCIPAL_REDRAW\",\"AMOUNT\",\"EXPECTED_DISRBUSEMENT_DATE\",\"DISBURSEMENT_TRANSACTION_KEY\",\"ACCOUNT_NAME\",\"ACCOUNT_ID\",\"ACCOUNT_HOLDER_TYPE\",\"LOAN_RISK_LEVELS_SUMMARY\",\"CODE\",\"SYMBOL\",\"ID\",\"OWNER_KEY\",\"OWNER_TYPE\",\"LOAN_LOCKED_OPERATIONS\",\"ENCODED_KEY\",\"NAME\",\"TAX_SOURCE_NAME\",\"INTEREST_COMMISSION\",\"FUNDS_AMOUNT\",\"FUNDING_PERCENTAGE\",\"NUMBER_OF_FUNDS\",\"FUNDS_ENABLED\",\"SHORT_MONTH_HANDLING_METHOD\",\"FIXED_DAYS_OF_MONTH\",\"METHOD\",\"AMOUNT\",\"PERCENTAGE\",\"TOTAL_DUE_AMOUNT\",\"TOTAL_DUE_PERCENTAGE\",\"FLOOR\",\"TOTAL_DUE_FLOOR\",\"CEILING\",\"INCLUDE_INTEREST\",\"INCLUDE_FEES\",\"EXPECTED_DISBURSEMENT_DATE\",\"DISBURSEMENT_DATE\",\"NAME\",\"TARGET_SAVINGS_ACCOUNT_NAME\",\"NAME\",\"TRIGGER\",\"AMOUNT\",\"LOAN_PRODUCT_TYPE\",\"REDRAW_ACCEPTANCE\",\"AMORTIZATION_METHOD\",\"TOLERANCE_CALCULATION_METHOD\"]}",
#             "request_uri": "/desktop/dispatch/GetLoanAccountExpandedDataItem",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:14.037Z",
#             "request_method": "POST",
#             "request_payload": "{\"backgroundProcessType\":\"REVERSE_TRANSACTION\",\"userKey\":\"8a195d1870f206b3017115ed0a0706bb\",\"entityKey\":\"8a19261d71ea2b3a0171ef25bb2e15f8\",\"states\":[\"IN_PROGRESS\",\"TO_BE_CANCELED\",\"QUEUED\"],\"entityType\":\"LOAN_ACCOUNT\"}",
#             "request_uri": "/desktop/dispatch/GetBackgroundTaskProgress",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:13.858Z",
#             "request_method": "POST",
#             "request_payload": "{\"loadAccountHasTrasactions\":true,\"accountKey\":\"8a19261d71ea2b3a0171ef25bb2e15f8\",\"loadRepayments\":true,\"loadProductName\":true,\"loadRecepientNameAndId\":true,\"loadProduct\":true,\"loadCustomFields\":true,\"loadAccountLinkingInfo\":true,\"loadGuaranteesInfo\":true,\"loadInvestorFundsInfo\":true}",
#             "request_uri": "/desktop/dispatch/GetLoanAccount",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:13.727Z",
#             "request_method": "POST",
#             "request_payload": "{\"fetchLoanAccounts\":true,\"fetchSavingsAccounts\":true,\"savingsAccountsFilter\":{\"detailsLevel\":\"BASIC\",\"branchSelectionType\":\"ALL\",\"centreSelectionType\":\"ALL\",\"creditOfficerSelectionType\":\"ALL\",\"creditOfficerKey\":\"8a195d1870f206b3017115ed0a0706bb\",\"branchFieldName\":\"assignedBranchKey\",\"centreFieldName\":\"assignedCentreKey\",\"userFieldName\":\"assignedUserKey\",\"accountStates\":[\"PENDING_APPROVAL\",\"APPROVED\",\"ACTIVE\",\"ACTIVE_IN_ARREARS\",\"MATURED\",\"LOCKED\",\"DORMANT\",\"CLOSED\",\"CLOSED_WRITTEN_OFF\",\"WITHDRAWN\",\"CLOSED_REJECTED\"],\"accountHolderKey\":\"8a19261d71ea2b3a0171ef22d15315da\",\"accountHolderType\":\"CLIENT\"},\"loanAccountsFilter\":{\"detailsLevel\":\"BASIC\",\"branchSelectionType\":\"ALL\",\"centreSelectionType\":\"ALL\",\"creditOfficerSelectionType\":\"ALL\",\"branchFieldName\":\"assignedBranchKey\",\"centreFieldName\":\"assignedCentreKey\",\"userFieldName\":\"assignedUserKey\",\"accountStates\":[\"PARTIAL_APPLICATION\",\"PENDING_APPROVAL\",\"APPROVED\",\"ACTIVE\",\"ACTIVE_IN_ARREARS\",\"CLOSED\",\"CLOSED_WRITTEN_OFF\",\"CLOSED_REJECTED\"],\"accountHolderKey\":\"8a19261d71ea2b3a0171ef22d15315da\",\"accountHolderType\":\"CLIENT\",\"currentUserKey\":\"8a195d1870f206b3017115ed0a0706bb\"}}",
#             "request_uri": "/desktop/dispatch/GetAccounts",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:13.636Z",
#             "request_method": "POST",
#             "request_payload": "{\"ownerKey\":\"8a19261d71ea2b3a0171ef22d15315da\",\"ownerType\":\"CLIENT\"}",
#             "request_uri": "/desktop/dispatch/GetLinesOfCredit",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:13.509Z",
#             "request_method": "POST",
#             "request_payload": "{\"clientKey\":\"8a19261d71ea2b3a0171ef22d15315da\",\"ownerType\":\"CLIENT\",\"loadSecuredLoanAccountsSummaries\":false,\"loadSecuredLoanAccountsCount\":true,\"loadNonClosedSecuredLoanAccountsCount\":true}",
#             "request_uri": "/desktop/dispatch/GetSecuredLoanAccountsSummaries",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         },
#         {
#             "client_ip": "62.140.137.94",
#             "event_source": "UI",
#             "occurred_at": "2020-05-07T12:49:13.399Z",
#             "request_method": "POST",
#             "request_payload": "{\"ownerKey\":\"8a19261d71ea2b3a0171ef22d15315da\",\"type\":\"CLIENT\"}",
#             "request_uri": "/desktop/dispatch/GetDisplaySummary",
#             "resource": "0",
#             "resource_fragment": "client.id=8a19261d71ea2b3a0171ef22d15315da.loan_account=8a19261d71ea2b3a0171ef25bb2e15f8.tab=0",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36",
#             "username": "michaelgbp"
#         }
#     ],
#     "from": 0,
#     "size": 10,
#     "totalItemsCount": 14247
# }

# %% [markdown]
# ## Get events from a previous point in time

# %%
HEADERS = {'apikey': '{{mnenv_apikey}}'}
PARAMS = {'size': "10", 'occurred_at[lt]': '2020-05-01T09:30:59.872Z'}
r = GET('{{envMN}}/v1/events', headers=HEADERS, params=PARAMS, headerparts=APIKEYS)
PRINT(r)
# Out:
# API status: 200
# JSON Response:
# {
#     "events": [
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:59.771Z",
#             "request_method": "POST",
#             "request_payload": "{\"ownerKey\":\"8a193db771bfd66a0171ca28f41b3492\",\"ownerType\":\"CLIENT\"}",
#             "request_uri": "/desktop/dispatch/GetLinesOfCredit",
#             "resource": "client",
#             "resource_fragment": "client.id=8a193db771bfd66a0171ca28f41b3492.type=indiv",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:59.649Z",
#             "request_method": "POST",
#             "request_payload": "{\"clientKey\":\"8a193db771bfd66a0171ca28f41b3492\",\"ownerType\":\"CLIENT\",\"loadSecuredLoanAccountsSummaries\":false,\"loadSecuredLoanAccountsCount\":true,\"loadNonClosedSecuredLoanAccountsCount\":true}",
#             "request_uri": "/desktop/dispatch/GetSecuredLoanAccountsSummaries",
#             "resource": "client",
#             "resource_fragment": "client.id=8a193db771bfd66a0171ca28f41b3492.type=indiv",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:59.539Z",
#             "request_method": "POST",
#             "request_payload": "{\"ownerKey\":\"8a193db771bfd66a0171ca28f41b3492\",\"type\":\"CLIENT\"}",
#             "request_uri": "/desktop/dispatch/GetDisplaySummary",
#             "resource": "client",
#             "resource_fragment": "client.id=8a193db771bfd66a0171ca28f41b3492.type=indiv",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:59.537Z",
#             "request_method": "POST",
#             "request_payload": "{\"types\":[\"CLIENT_INFO\"],\"loadCustomFieldSelection\":false,\"loadCustomFieldLinks\":false,\"entityLinkedKey\":\"8a195d1870f206b3017115ed0d4506c5\"}",
#             "request_uri": "/desktop/dispatch/GetCustomFieldSets",
#             "resource": "client",
#             "resource_fragment": "client.id=8a193db771bfd66a0171ca28f41b3492.type=indiv",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:59.357Z",
#             "request_method": "POST",
#             "request_payload": "{\"clientKey\":\"8a193db771bfd66a0171ca28f41b3492\"}",
#             "request_uri": "/desktop/dispatch/GetClient",
#             "resource": "client",
#             "resource_fragment": "client.id=8a193db771bfd66a0171ca28f41b3492.type=indiv",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:58.682Z",
#             "request_method": "POST",
#             "request_payload": "{\"client\":{\"state\":\"INACTIVE\",\"id\":\"589304138\",\"loanCycle\":0,\"groupLoanCycle\":0,\"clientRoleKey\":\"8a195d1870f206b3017115ed0d4506c5\",\"preferredLanguage\":\"ENGLISH\"},\"customInformation\":[],\"toBeDeletedAttachmentDocuments\":[],\"notificationDetails\":{\"sendEmail\":false,\"sendSMS\":false,\"sendNotification\":true},\"associatedGroups\":[]}",
#             "request_uri": "/desktop/dispatch/StoreClient",
#             "resource": "createclient",
#             "resource_fragment": "createclient.client_role_id=8a195d1870f206b3017115ed0d4506c5",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:58.576Z",
#             "request_method": "POST",
#             "request_payload": "{\"idNumbers\":[],\"client\":{}}",
#             "request_uri": "/desktop/dispatch/GetDuplicatedClients",
#             "resource": "createclient",
#             "resource_fragment": "createclient.client_role_id=8a195d1870f206b3017115ed0d4506c5",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:53.167Z",
#             "request_method": "POST",
#             "request_payload": "{\"customFieldKeys\":[\"8a195d1870f206b3017115ed0f930862\"]}",
#             "request_uri": "/desktop/dispatch/GetCustomFieldDependencyInfo",
#             "resource": "createclient",
#             "resource_fragment": "createclient.client_role_id=8a195d1870f206b3017115ed0d4506c5",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:53.013Z",
#             "request_method": "POST",
#             "request_payload": "{}",
#             "request_uri": "/desktop/dispatch/GetGroupCount",
#             "resource": "createclient",
#             "resource_fragment": "createclient.client_role_id=8a195d1870f206b3017115ed0d4506c5",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         },
#         {
#             "client_ip": "95.98.189.119",
#             "event_source": "UI",
#             "occurred_at": "2020-05-01T09:30:52.985Z",
#             "request_method": "POST",
#             "request_payload": "{\"accountHolders\":[{\"accountHolderType\":\"CLIENT\"}],\"notificationEvents\":[\"CLIENT_CREATED\"]}",
#             "request_uri": "/desktop/dispatch/GetDefaultNotifications",
#             "resource": "createclient",
#             "resource_fragment": "createclient.client_role_id=8a195d1870f206b3017115ed0d4506c5",
#             "response_code": 200.0,
#             "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
#             "username": "pari"
#         }
#     ],
#     "from": 0,
#     "size": 10,
#     "totalItemsCount": 13041
# }

# %%
HEADERS = {'Accept': 'application/vnd.mambu.v2+json'}
PARAMS = {'detailsLevel': 'FULL'}
r = GET('{{env4}}/loans/IBFY994', headers=HEADERS, params=PARAMS)
PRINT(r)
# Out:
# API status: 200
# JSON Response:
# {
#     "_SOM1": {
#         "FromAccountID": "32323",
#         "PayeeAccountID": "12221",
#         "PayeeReference": "3232",
#         "PayeeSortCode": "232",
#         "PayerReference": "3232",
#         "PaymentType": "Domestic",
#         "SOActive": "TRUE"
#     },
#     "accountArrearsSettings": {
#         "dateCalculationMethod": "ACCOUNT_FIRST_WENT_TO_ARREARS",
#         "encodedKey": "8a818f1671acaf300171b61f75d3764e",
#         "nonWorkingDaysMethod": "EXCLUDED",
#         "toleranceCalculationMethod": "ARREARS_TOLERANCE_PERIOD",
#         "tolerancePercentageOfOutstandingPrincipal": 0,
#         "tolerancePeriod": 0
#     },
#     "accountHolderKey": "8a818f1671acaf300171b61be9da7645",
#     "accountHolderType": "GROUP",
#     "accountState": "ACTIVE",
#     "accruedInterest": 0,
#     "accruedPenalty": 0,
#     "activationTransactionKey": "8a818f1671acaf300171b620506d7671",
#     "allowOffset": false,
#     "approvedDate": "2020-04-26T12:55:03+02:00",
#     "arrearsTolerancePeriod": 0,
#     "assets": [],
#     "assignedBranchKey": "8a818f1671acaf300171b15b6a774d8d",
#     "balances": {
#         "feesBalance": 0,
#         "feesDue": 0,
#         "feesPaid": 0,
#         "holdBalance": 0,
#         "interestBalance": 0,
#         "interestDue": 0,
#         "interestFromArrearsBalance": 0,
#         "interestFromArrearsDue": 0,
#         "interestFromArrearsPaid": 0,
#         "interestPaid": 0,
#         "penaltyBalance": 0,
#         "penaltyDue": 0,
#         "penaltyPaid": 0,
#         "principalBalance": 5000000.0,
#         "principalDue": 0,
#         "principalPaid": 0,
#         "redrawBalance": 0
#     },
#     "creationDate": "2020-04-26T12:54:07+02:00",
#     "disbursementDetails": {
#         "disbursementDate": "2020-04-26T12:55:07+02:00",
#         "encodedKey": "8a818f1671acaf300171b61d9589764c",
#         "expectedDisbursementDate": "2020-04-26T12:55:07+02:00",
#         "fees": [],
#         "transactionDetails": {
#             "encodedKey": "8a818f1671acaf300171b61f75d3764d",
#             "internalTransfer": false,
#             "transactionChannelId": "cash",
#             "transactionChannelKey": "8a818e74677a2e9201677ec2b4c336a6"
#         }
#     },
#     "encodedKey": "8a818f1671acaf300171b61d9589764b",
#     "fundingSources": [],
#     "futurePaymentsAcceptance": "NO_FUTURE_PAYMENTS",
#     "guarantors": [],
#     "id": "IBFY994",
#     "interestFromArrearsAccrued": 0,
#     "interestSettings": {
#         "accrueInterestAfterMaturity": false,
#         "accrueLateInterest": true,
#         "interestApplicationMethod": "AFTER_DISBURSEMENT",
#         "interestBalanceCalculationMethod": "ONLY_PRINCIPAL",
#         "interestCalculationMethod": "DECLINING_BALANCE_DISCOUNTED",
#         "interestChargeFrequency": "ANNUALIZED",
#         "interestRate": 0,
#         "interestRateSource": "FIXED_INTEREST_RATE",
#         "interestType": "SIMPLE_INTEREST"
#     },
#     "lastAccountAppraisalDate": "2020-05-01T00:00:41+02:00",
#     "lastModifiedDate": "2020-04-26T12:55:07+02:00",
#     "latePaymentsRecalculationMethod": "LAST_INSTALLMENT_INCREASE",
#     "loanAmount": 5000000.0,
#     "loanName": "Standing Order (scheduler)",
#     "paymentMethod": "HORIZONTAL",
#     "penaltySettings": {
#         "loanPenaltyCalculationMethod": "NONE"
#     },
#     "prepaymentSettings": {},
#     "productTypeKey": "8a818f1671acaf300171b251df6e6057",
#     "scheduleSettings": {
#         "gracePeriod": 0,
#         "gracePeriodType": "NONE",
#         "hasCustomSchedule": false,
#         "paymentPlan": [],
#         "periodicPayment": 321.0,
#         "principalRepaymentInterval": 1,
#         "repaymentInstallments": 24,
#         "repaymentPeriodCount": 1,
#         "repaymentPeriodUnit": "MONTHS",
#         "repaymentScheduleMethod": "FIXED",
#         "scheduleDueDatesMethod": "INTERVAL"
#     },
#     "tranches": []
# }

# %%
APIKEYS
# Out:
# {'mnenv_apikey': 'sJoBRBTjNBS0H5OWqNDZS1U1ilrJ2tEC'}
